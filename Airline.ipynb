# %% [markdown]
# # LOAD THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from openpyxl import load_workbook

# %% [markdown]
# # HIERARCHICAL CLUSTERING

# %%
Al=pd.DataFrame()

# %%
data='https://excelr.s3.nl-ams.scw.cloud/DataScience-Assignments/Assignments/clusters/EastWestAirlines.xlsx'
ds=pd.ExcelFile(data)

for sheet in ds.sheet_names:
  df_tmp=ds.parse(sheet)
Al=Al.append(df_tmp,ignore_index=True,sort=False)
csvfile='sample.csv'
Al.to_csv(csvfile,index=False)
Al.head()
# Out:
# C:\Users\Anuj M\AppData\Local\Temp\ipykernel_8404\3966688281.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Al=Al.append(df_tmp,ignore_index=True,sort=False)
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# ...

# %%
## from description we drop the telecom and CHAR columns
Al1=Al.drop(['ID#','cc1_miles','cc2_miles','cc3_miles','Days_since_enroll','Award?'],axis=1)
Al1
# Out:
#       Balance  Qual_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# 0       28143           0          174            1                  0
# 1       19244           0          215            2                  0
# 2       41354           0         4123            4                  0
# 3       14776           0          500            1                  0
# 4       97752           0        43300           26               2077
# ...       ...         ...          ...          ...                ...
# 3994    18476           0         8525            4                200
# 3995    64385           0          981            5                  0
# 3996    73597           0        25447            8                  0
# 3997    54899           0          500            1                500
# 3998     3016           0            0            0                  0
#
#       Flight_trans_12
# 0                   0
# 1                   0
# 2                   0
# ...

# %%
def func(i):
  x=(i-i.min())/(i.max()-i.min())
  return(x)

# %%
df=func(Al1)
df
# Out:
#        Balance  Qual_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# 0     0.016508         0.0     0.000660     0.011628           0.000000
# 1     0.011288         0.0     0.000815     0.023256           0.000000
# 2     0.024257         0.0     0.015636     0.046512           0.000000
# 3     0.008667         0.0     0.001896     0.011628           0.000000
# 4     0.057338         0.0     0.164211     0.302326           0.067398
# ...        ...         ...          ...          ...                ...
# 3994  0.010837         0.0     0.032330     0.046512           0.006490
# 3995  0.037766         0.0     0.003720     0.058140           0.000000
# 3996  0.043169         0.0     0.096505     0.093023           0.000000
# 3997  0.032202         0.0     0.001896     0.011628           0.016225
# 3998  0.001769         0.0     0.000000     0.000000           0.000000
#
#       Flight_trans_12
# 0            0.000000
# 1            0.000000
# 2            0.000000
# ...

# %%
dendrogram=sch.dendrogram(sch.linkage(df,method='complete'))

# %%
dendrogram=sch.dendrogram(sch.linkage(df,method='average'))

# %%
hc=AgglomerativeClustering(n_clusters=3,linkage='complete')

# %%
y=hc.fit_predict(df)
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Al1['cluster']=y
Al1
# Out:
#       Balance  Qual_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# 0       28143           0          174            1                  0
# 1       19244           0          215            2                  0
# 2       41354           0         4123            4                  0
# 3       14776           0          500            1                  0
# 4       97752           0        43300           26               2077
# ...       ...         ...          ...          ...                ...
# 3994    18476           0         8525            4                200
# 3995    64385           0          981            5                  0
# 3996    73597           0        25447            8                  0
# 3997    54899           0          500            1                500
# 3998     3016           0            0            0                  0
#
#       Flight_trans_12  cluster
# 0                   0        0
# 1                   0        0
# ...

# %%
Al1['cluster'].values
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Al
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Al1=Al.drop(['ID#'],axis=1)
Al1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
def func(i):
  x=(i-i.min())/(i.max()-i.min())
  return(x)

# %%
bf=func(Al1)
bf
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
dendrogram=sch.dendrogram(sch.linkage(bf,method='complete'))

# %%
dendrogram=sch.dendrogram(sch.linkage(bf,method='average'))

# %%
    yc=AgglomerativeClustering(n_clusters=8,linkage='complete')

# %%
f=yc.fit_predict(bf)

# %%
Al1['clusters']=f
Al1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # K-MEANS CLUSTERING

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
def norm_func(i):
  x=(i-i.min())/(i.max()-i.min())
  return(x)

# %%
fd=norm_func(Al1.iloc[:,1:])
fd
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0            0.0       0.00        0.0        0.0     0.000660     0.011628
# 1            0.0       0.00        0.0        0.0     0.000815     0.023256
# 2            0.0       0.00        0.0        0.0     0.015636     0.046512
# 3            0.0       0.00        0.0        0.0     0.001896     0.011628
# 4            0.0       0.75        0.0        0.0     0.164211     0.302326
# ...          ...        ...        ...        ...          ...          ...
# 3994         0.0       0.00        0.0        0.0     0.032330     0.046512
# 3995         0.0       0.00        0.0        0.0     0.003720     0.058140
# 3996         0.0       0.50        0.0        0.0     0.096505     0.093023
# 3997         0.0       0.00        0.0        0.0     0.001896     0.011628
# 3998         0.0       0.00        0.0        0.0     0.000000     0.000000
#
# ...

# %%
wcss=[]
for i in range(1,16):
  kmeans=KMeans(n_clusters=i,random_state=0)
  kmeans.fit(fd)
  wcss.append(kmeans.inertia_)
plt.plot(range(1,16),wcss)
plt.title('Elbow Curve')
plt.xlabel('clusters')
plt.ylabel('wcss')
# Out:
# Text(0, 0.5, 'wcss')

# %%
## from Elbow Curve we have to decide 8 clusters
m1=KMeans(n_clusters=8)
m1.fit(fd)
# Out:
# KMeans()

# %%
m1.labels_
# Out:
# array([6, 6, 6, ..., 3, 2, 2])

# %%
md=pd.Series(m1.labels_)
Al1['cluster']=md
Al1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Al1.iloc[:,1:11].groupby(Al1.cluster).mean()
# Out:
#          Qual_miles  cc1_miles  cc2_miles  cc3_miles   Bonus_miles  \
# cluster
# 0         56.013468   3.703704   1.000000   1.026936  34050.390572
# 1        225.536232   1.153623   1.034783   1.000000   8717.431884
# 2         94.131783   1.070736   1.016473   1.006783   3244.520349
# 3        132.434694   3.432653   1.002041   1.002041  29314.585714
# 4        358.734756   1.158537   1.030488   1.018293   8990.250000
# 5         89.616822   3.473520   1.003115   1.018692  28917.722741
# 6         89.903226   1.122120   1.019585   1.001152   3467.074885
# 7        299.883648   4.660377   1.000000   1.062893  70718.415094
#
#          Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# cluster
# 0          17.087542         223.037037         0.693603        6119.387205
# 1          10.162319        1041.318841         3.052174        2710.771014
# 2           6.173450         212.850775         0.603682        1992.402132
# ...

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
Al=pd.DataFrame()
data='https://excelr.s3.nl-ams.scw.cloud/DataScience-Assignments/Assignments/clusters/EastWestAirlines.xlsx'
ds=pd.ExcelFile(data)

for sheet in ds.sheet_names:
  df_tmp=ds.parse(sheet)
Al=Al.append(df_tmp,ignore_index=True,sort=False)
csvfile='sample.csv'
Al.to_csv(csvfile,index=False)
# Out:
# C:\Users\Anuj M\AppData\Local\Temp\ipykernel_8404\4140821951.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Al=Al.append(df_tmp,ignore_index=True,sort=False)

# %%
Al.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
array=Al.values
array
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
stscaler=StandardScaler().fit(array)
x=stscaler.transform(array)
x
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbs=DBSCAN(eps=2,min_samples=12)
dbs.fit(x)
# Out:
# DBSCAN(eps=2, min_samples=12)

# %%
y=dbs.fit_predict(x)

# %%
dbs.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(y,columns=['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([Al,cl],axis=1)
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...
